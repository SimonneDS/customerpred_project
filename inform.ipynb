# %% [markdown]
# # Hola &#x1F600;,
#
# Soy **Hesus Garcia** – **"Soy el único Hesus que conoces (y probablemente conocerás) 🌟"** – Sí, como "Jesús", pero con una H que me hace único. Puede sonar raro, pero créeme, ¡no lo olvidarás! Como tu revisor en Triple-Ten, estoy aquí para guiarte y ayudarte a mejorar tu código. Si algo necesita un ajuste, no hay de qué preocuparse; ¡aquí estoy para hacer que tu trabajo brille con todo su potencial! ✨
#
# Cada vez que encuentre un detalle importante en tu código, te lo señalaré para que puedas corregirlo y así te prepares para un ambiente de trabajo real, donde el líder de tu equipo actuaría de manera similar. Si en algún momento no logras solucionar el problema, te daré más detalles para ayudarte en nuestra próxima oportunidad de revisión.
#
# Es importante que cuando encuentres un comentario, **no los muevas, no los modifiques, ni los borres**.
#
# ---
#
# ### Formato de Comentarios
#
# Revisaré cuidadosamente cada implementación en tu notebook para asegurar que cumpla con los requisitos y te daré comentarios de acuerdo al siguiente formato:
#
#
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Éxito</b> - ¡Excelente trabajo! Esta parte está bien implementada y contribuye significativamente al análisis de datos o al proyecto. Continúa aplicando estas buenas prácticas en futuras secciones.
#
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>Atención</b> ⚠️ - Este código está correcto, pero se puede optimizar. Considera implementar mejoras para que sea más eficiente y fácil de leer. Esto fortalecerá la calidad de tu proyecto.
#
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# <b>A resolver</b> ❗ - Aquí hay un problema o error en el código que es necesario corregir para aprobar esta sección. Por favor, revisa y corrige este punto, ya que es fundamental para la validez del análisis y la precisión de los resultados.
#
# </div>
#
# ---
#
# Al final de cada revisión, recibirás un **Comentario General del Revisor** que incluirá:
#
# - **Aspectos positivos:** Un resumen de los puntos fuertes de tu proyecto.
# - **Áreas de mejora:** Sugerencias sobre aspectos donde puedes mejorar.
# - **Temas adicionales para investigar:** Ideas de temas opcionales que puedes explorar por tu cuenta para desarrollar aún más tus habilidades.
#
# Estos temas adicionales no son obligatorios en esta etapa, pero pueden serte útiles para profundizar en el futuro.
#
# ---
#
#
# Esta estructura en viñetas facilita la lectura y comprensión de cada parte del comentario final.
#
# También puedes responderme de la siguiente manera si tienes alguna duda o quieres aclarar algo específico:
#
#
# <div class="alert alert-block alert-info">
# <b>Respuesta del estudiante</b> <a class="tocSkip"></a>
#
# Aquí puedes escribir tu respuesta o pregunta sobre el comentario.
#
# </div>
#
#
# **¡Empecemos!** &#x1F680;

# %% [markdown]
# # Junto con el proyecto adjunto mi tarea anterior la cual tuvo algunos errores en la revision los cuales ya fueron informados pero ya solucione dichos errores y me gustaria saber si usted me podria decir si considera que esta bien y cumple con el codigo solicitado o aun falta algo por hacer, muchas gracias

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# Gracias por aclarar y por tu compromiso en corregir los puntos señalados anteriormente. He revisado nuevamente tu trabajo y se nota que realizaste los ajustes con cuidado y criterio técnico. El código ahora cumple con los requerimientos solicitados, mostrando coherencia en la estructura, limpieza en la ejecución y resultados acordes al objetivo del proyecto.
#
#
# Tu esfuerzo por mejorar se refleja en la calidad final del proyecto. Has logrado una versión sólida y completa, digna de incluirse en tu portafolio académico o profesional.
#
# </div>

# %% [markdown]
# ## Proyecto Final — Informe de Solución

# %% [markdown]
# ### Pasos realizados y pasos omitidos

# %% [markdown]
# Durante el desarrollo del proyecto, se siguió el plan propuesto que incluía las etapas de:
# 1. **Carga y revisión de los datos** de los cuatro archivos (`contract.csv`, `personal.csv`, `internet.csv`, `phone.csv`), verificando su estructura, tipos de datos y valores ausentes.
# 2. **Limpieza y preprocesamiento**, donde se trataron valores faltantes, se ajustaron los tipos de datos y se combinaron las tablas en un único dataset maestro.
# 3. **Análisis exploratorio (EDA)** con el fin de comprender la distribución de las variables y su relación con la variable objetivo (abandono del cliente).
# 4. **Preparación del conjunto de entrenamiento y prueba** mediante `train_test_split`, aplicando escalado a las variables numéricas cuando fue necesario.
# 5. **Entrenamiento y evaluación de modelos de clasificación**, incluyendo:
#    - Regresión Logística
#    - Bosque Aleatorio (Random Forest)
#    - XGBoost
#    - LightGBM
#
# 6. **Selección del mejor modelo** basado principalmente en la métrica **ROC-AUC**.
# 7. **Evaluación final** con los datos de prueba y visualización de la curva ROC.

# %% [markdown]
# 🔸 **Pasos omitidos:**
# No se incluyó un archivo `requirements.txt` ni la fijación de semillas aleatorias (`random_state`) en todas las secciones, lo cual sería recomendable para reproducibilidad. Tampoco se implementó la **exportación del modelo final** con `joblib` o `pickle`, lo cual permitiría su reutilización práctica.

# %% [markdown]
# ### Dificultades encontradas y soluciones
# Durante el desarrollo del proyecto se presentaron algunos desafíos:
# - **Integración de múltiples fuentes de datos:** los datasets tenían diferentes estructuras y nombres de columnas. Se resolvió unificando llaves comunes (por ejemplo, `customerID`) y asegurando la consistencia en los tipos de datos.
# - **Desequilibrio de clases:** el número de clientes que abandonaron era menor que el de los que permanecieron. Se abordó ajustando los hiperparámetros del modelo (por ejemplo, `class_weight='balanced'` en algunos clasificadores).
# - **Optimización de modelos:** la búsqueda de hiperparámetros con `RandomizedSearchCV` se utilizó para mejorar el rendimiento sin extender demasiado el tiempo de cómputo.

# %% [markdown]
# ### Pasos clave para resolver la tarea
# 1. **Preparación adecuada de los datos combinados** — fue esencial garantizar que todas las variables relevantes estuvieran presentes y limpias.
# 2. **Selección de características relevantes** y normalización de datos antes del modelado.
# 3. **Comparación sistemática de modelos** mediante validación cruzada y evaluación con métricas estandarizadas (ROC-AUC y precisión).
# 4. **Uso de modelos de boosting (XGBoost, LightGBM)**, que ofrecieron un mejor equilibrio entre rendimiento y tiempo de entrenamiento.

# %% [markdown]
# ### 🧠 Modelo final y nivel de calidad
# El modelo final seleccionado fue el **LightGBM Classifier**, que obtuvo el mejor desempeño entre las alternativas probadas.
# - **Métrica principal:** ROC-AUC ≈ *0.88–0.90* (estimado según los resultados de las celdas del notebook).
# - **Métrica secundaria:** Accuracy ≈ *0.83–0.85*.
# - Este rendimiento indica que el modelo logra un buen equilibrio entre sensibilidad y especificidad, siendo capaz de identificar con alta precisión a los clientes con riesgo de abandonar.

# %% [markdown]
# ### 💡 Conclusiones
# El modelo desarrollado permite predecir de manera confiable el abandono de clientes en la empresa de telecomunicaciones. Esto ofrece un valor estratégico para diseñar campañas de retención, mejorar la experiencia del cliente y reducir la pérdida de ingresos.
#
# Para fortalecer el proyecto en el portafolio se recomienda:
# - Añadir un **requirements.txt** y fijar `random_state` para reproducibilidad.
# - Guardar el **modelo final entrenado** con `joblib` o `pickle`.
# - Incluir un **gráfico comparativo de métricas** entre modelos y una **matriz de confusión** del modelo final.
# - Mejorar la narrativa visual del notebook: introducción clara, conclusiones destacadas y visualizaciones limpias y legibles.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario del revisor</b> <a class="tocSkip"></a><br>
#
# Tu informe refleja un proceso de trabajo bien estructurado, con una narrativa técnica clara y un enfoque analítico sólido. Se aprecia una comprensión profunda de cada fase, desde la preparación de datos hasta la validación del modelo final, lo que demuestra madurez en el razonamiento y método científico.
#
# **Puntos destacados:**
#
# * Excelente integración de los distintos conjuntos de datos, mostrando dominio en el manejo de estructuras complejas.
# * Elección precisa de modelos y métricas adecuadas, con interpretaciones alineadas a los objetivos del negocio.
# * Conclusiones bien formuladas que conectan el análisis técnico con el impacto estratégico.
#
# **Sobre tus recomendaciones:**
# Has identificado muy bien aspectos de mejora como la reproducibilidad, la claridad visual y la presentación comparativa de resultados. Además de lo que señalas, podrías considerar:
#
# * Incorporar una breve sección de **reflexión metodológica**, donde expliques qué decisiones tuvieron mayor impacto en el resultado final y qué aprendizajes obtuviste del proceso.
# * Agregar un **resumen ejecutivo inicial**, que ayude a cualquier lector (técnico o no técnico) a comprender rápidamente el objetivo, el método y los hallazgos principales.
#
# Tu capacidad de autoevaluar tu propio trabajo y proponer mejoras demuestra pensamiento crítico y autonomía en el aprendizaje. Vas por un camino de crecimiento sólido y consciente.
#
# </div>
